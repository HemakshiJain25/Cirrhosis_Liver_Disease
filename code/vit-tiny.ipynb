# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/507/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/36.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/36.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/481/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/4.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/9.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/2.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/10.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/7.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/5.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/3.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/8.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/6.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/4.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/9.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/2.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/10.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/7.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/5.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/3.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/8.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/6.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/53/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/498/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/37.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/36.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/37.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/36.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/489/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/472/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/9.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/10.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/8.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/9.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/10.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/8.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/500/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/497/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/2/488/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/50/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/37.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/39.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/38.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/36.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/37.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/39.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/38.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/36.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/506/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/37.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/38.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/36.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/37.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/38.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/36.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/483/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/512/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/509/images/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/509/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/509/images/9.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/509/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/509/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/509/images/10.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/validation/3/509/images/18.png
# ...
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/357/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/297/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/10.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/10.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/118/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/191/masks/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/9.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/10.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/7.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/8.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/images/26.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/35.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/11.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/31.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/33.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/9.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/14.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/20.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/10.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/18.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/21.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/12.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/28.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/22.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/34.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/7.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/29.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/17.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/16.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/8.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/24.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/32.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/23.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/15.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/30.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/27.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/13.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/25.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/19.png
# /kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train/1/319/masks/26.png

# %%
import numpy as np
np.random.seed(42) 
import pandas as pd
import os
import matplotlib.pyplot as plt
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader, Dataset
from torchsummary import summary

# %%
num_classes = len(os.listdir('/kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train'))
print(num_classes)
# Out:
# 3

# %%
# Custom Dataset Class


class LiverDiseaseDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, _, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')
        
        if self.transform:
            image = self.transform(image)
        
        label_idx = class_names.index(label)  # Convert label to index
        return image, label_idx

# Get Class Names from Train Directory
class_names = os.listdir('/kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train')

# %%
train_dir = '/kaggle/input/liver-diseases-dataset/Liver Disease Dataset/train'
training_data = []

for label in os.listdir(train_dir):
    label_dir = os.path.join(train_dir,label)
    for patient in os.listdir(label_dir):
        patient_dir = os.path.join(label_dir, patient)
        images_dir = os.path.join(patient_dir, 'images')

        for filename in os.listdir(images_dir):
            image_path = os.path.join(images_dir, filename)
            training_data.append([image_path, patient, label])

# %%
test_dir = '/kaggle/input/liver-diseases-dataset/Liver Disease Dataset/test'
testing_data = []

for label in os.listdir(test_dir):
    label_dir = os.path.join(test_dir,label)
    for patient in os.listdir(label_dir):
        patient_dir = os.path.join(label_dir, patient)
        images_dir = os.path.join(patient_dir, 'images')

        for filename in os.listdir(images_dir):
            image_path = os.path.join(images_dir, filename)
            testing_data.append([image_path, patient, label])

# %%
valid_dir = '/kaggle/input/liver-diseases-dataset/Liver Disease Dataset/test'
validation_data = []

for label in os.listdir(valid_dir):
    label_dir = os.path.join(test_dir,label)
    for patient in os.listdir(label_dir):
        patient_dir = os.path.join(label_dir, patient)
        valid_dir = os.path.join(patient_dir, 'images')

        for filename in os.listdir(images_dir):
            image_path = os.path.join(images_dir, filename)
            validation_data.append([image_path, patient, label])

# %%
image_path = training_data[0][0]
image = Image.open(image_path)
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
import torchvision.transforms as transforms

data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),  
        transforms.RandomRotation(degrees=5),   # Random horizontal flip
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
}

# %%
train_dataset = LiverDiseaseDataset(training_data, transform=data_transforms['train'])
val_dataset = LiverDiseaseDataset(validation_data, transform=data_transforms['val'])
test_dataset = LiverDiseaseDataset(testing_data, transform=data_transforms['test'])

# Create Data Loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
import timm
model = timm.create_model('vit_base_patch16_224', pretrained=True)  # Using pretrained ViT model
model.head = nn.Linear(model.head.in_features, num_classes)
# Out:
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]

# %%
criterion = nn.CrossEntropyLoss()  # For classification tasks
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)  # Move model to GPU
  # Move data to GPU

# %%
import torch.optim.lr_scheduler as lr_scheduler

# Define the scheduler (Example: StepLR reduces LR every 10 epochs by a factor of 0.1)
scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

num_epochs = 50

# Lists to store loss and accuracy values
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct / total

    # Store train loss and accuracy
    train_losses.append(epoch_loss)
    train_accuracies.append(train_accuracy)

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {train_accuracy:.2f}%")

    # Validation Phase
    model.eval()
    val_correct = 0
    val_total = 0
    val_loss = 0.0

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_epoch_loss = val_loss / len(val_loader)
    val_accuracy = 100 * val_correct / val_total

    # Store validation loss and accuracy
    val_losses.append(val_epoch_loss)
    val_accuracies.append(val_accuracy)

    print(f"Epoch [{epoch+1}/{num_epochs}], Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%\n")

    # Step the scheduler
    scheduler.step()

# Plot the training and validation loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, label="Train Loss", marker='o')
plt.plot(range(1, num_epochs + 1), val_losses, label="Validation Loss", marker='o')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.grid()

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_accuracies, label="Train Accuracy", marker='o')
plt.plot(range(1, num_epochs + 1), val_accuracies, label="Validation Accuracy", marker='o')
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.title("Train vs Validation Accuracy")
plt.legend()
plt.grid()

plt.show()
# Out:
# Epoch [1/50], Loss: 1.0253, Accuracy: 45.57%
# Epoch [1/50], Validation Loss: 1.2724, Validation Accuracy: 51.61%
#
# Epoch [2/50], Loss: 0.8046, Accuracy: 59.28%
# Epoch [2/50], Validation Loss: 1.9545, Validation Accuracy: 49.72%
#
# Epoch [3/50], Loss: 0.7045, Accuracy: 66.55%
# Epoch [3/50], Validation Loss: 1.6092, Validation Accuracy: 51.61%
#
# Epoch [4/50], Loss: 0.5381, Accuracy: 76.14%
# Epoch [4/50], Validation Loss: 2.1147, Validation Accuracy: 49.72%
#
# Epoch [5/50], Loss: 0.4068, Accuracy: 82.72%
# Epoch [5/50], Validation Loss: 2.1027, Validation Accuracy: 40.23%
#
# Epoch [6/50], Loss: 0.2923, Accuracy: 88.27%
# Epoch [6/50], Validation Loss: 3.4052, Validation Accuracy: 51.61%
#
# Epoch [7/50], Loss: 0.2063, Accuracy: 91.88%
# Epoch [7/50], Validation Loss: 2.7641, Validation Accuracy: 49.72%
#
# Epoch [8/50], Loss: 0.1461, Accuracy: 94.89%
# Epoch [8/50], Validation Loss: 4.1592, Validation Accuracy: 51.61%
#
# Epoch [9/50], Loss: 0.1439, Accuracy: 94.53%
# Epoch [9/50], Validation Loss: 3.7638, Validation Accuracy: 51.61%
#
# Epoch [10/50], Loss: 0.0987, Accuracy: 96.56%
# Epoch [10/50], Validation Loss: 2.9553, Validation Accuracy: 49.72%
#
# Epoch [11/50], Loss: 0.0329, Accuracy: 98.97%
# Epoch [11/50], Validation Loss: 3.5670, Validation Accuracy: 51.61%
#
# Epoch [12/50], Loss: 0.0112, Accuracy: 99.64%
# Epoch [12/50], Validation Loss: 4.1291, Validation Accuracy: 51.61%
#
# Epoch [13/50], Loss: 0.0071, Accuracy: 99.83%
# Epoch [13/50], Validation Loss: 4.5086, Validation Accuracy: 51.61%
#
# Epoch [14/50], Loss: 0.0032, Accuracy: 99.96%
# Epoch [14/50], Validation Loss: 4.9077, Validation Accuracy: 51.61%
#
# Epoch [15/50], Loss: 0.0035, Accuracy: 99.92%
# Epoch [15/50], Validation Loss: 5.4768, Validation Accuracy: 51.61%
#
# Epoch [16/50], Loss: 0.0041, Accuracy: 99.89%
# Epoch [16/50], Validation Loss: 5.5212, Validation Accuracy: 51.61%
#
# Epoch [17/50], Loss: 0.0031, Accuracy: 99.91%
# Epoch [17/50], Validation Loss: 5.4615, Validation Accuracy: 51.61%
#
# Epoch [18/50], Loss: 0.0024, Accuracy: 99.94%
# Epoch [18/50], Validation Loss: 6.0025, Validation Accuracy: 49.72%
#
# Epoch [19/50], Loss: 0.0013, Accuracy: 99.94%
# Epoch [19/50], Validation Loss: 7.0034, Validation Accuracy: 51.61%
#
# Epoch [20/50], Loss: 0.0011, Accuracy: 99.96%
# Epoch [20/50], Validation Loss: 7.4752, Validation Accuracy: 51.61%
#
# Epoch [21/50], Loss: 0.0029, Accuracy: 99.92%
# Epoch [21/50], Validation Loss: 6.7541, Validation Accuracy: 51.61%
#
# Epoch [22/50], Loss: 0.0016, Accuracy: 99.94%
# Epoch [22/50], Validation Loss: 6.6596, Validation Accuracy: 51.61%
#
# Epoch [23/50], Loss: 0.0011, Accuracy: 99.94%
# Epoch [23/50], Validation Loss: 6.8174, Validation Accuracy: 51.61%
#
# Epoch [24/50], Loss: 0.0006, Accuracy: 99.98%
# Epoch [24/50], Validation Loss: 6.7826, Validation Accuracy: 51.61%
#
# Epoch [25/50], Loss: 0.0020, Accuracy: 99.96%
# Epoch [25/50], Validation Loss: 6.8045, Validation Accuracy: 51.61%
#
# Epoch [26/50], Loss: 0.0012, Accuracy: 99.98%
# Epoch [26/50], Validation Loss: 6.8513, Validation Accuracy: 51.61%
#
# Epoch [27/50], Loss: 0.0012, Accuracy: 99.98%
# Epoch [27/50], Validation Loss: 6.9791, Validation Accuracy: 51.61%
#
# Epoch [28/50], Loss: 0.0015, Accuracy: 99.94%
# Epoch [28/50], Validation Loss: 7.0708, Validation Accuracy: 51.61%
#
# Epoch [29/50], Loss: 0.0011, Accuracy: 99.98%
# Epoch [29/50], Validation Loss: 6.9454, Validation Accuracy: 51.61%
#
# Epoch [30/50], Loss: 0.0004, Accuracy: 100.00%
# Epoch [30/50], Validation Loss: 7.0412, Validation Accuracy: 51.61%
#
# Epoch [31/50], Loss: 0.0003, Accuracy: 100.00%
# Epoch [31/50], Validation Loss: 7.0344, Validation Accuracy: 51.61%
#
# Epoch [32/50], Loss: 0.0004, Accuracy: 100.00%
# Epoch [32/50], Validation Loss: 7.0267, Validation Accuracy: 51.61%
#
# Epoch [33/50], Loss: 0.0003, Accuracy: 100.00%
# Epoch [33/50], Validation Loss: 7.0056, Validation Accuracy: 51.61%
#
# Epoch [34/50], Loss: 0.0005, Accuracy: 99.98%
# Epoch [34/50], Validation Loss: 6.9894, Validation Accuracy: 51.61%
#
# Epoch [35/50], Loss: 0.0007, Accuracy: 99.96%
# Epoch [35/50], Validation Loss: 6.9950, Validation Accuracy: 51.61%
#
# Epoch [36/50], Loss: 0.0004, Accuracy: 100.00%
# Epoch [36/50], Validation Loss: 7.0127, Validation Accuracy: 51.61%
#
# Epoch [37/50], Loss: 0.0003, Accuracy: 100.00%
# Epoch [37/50], Validation Loss: 7.0183, Validation Accuracy: 51.61%
#
# Epoch [38/50], Loss: 0.0007, Accuracy: 99.98%
# Epoch [38/50], Validation Loss: 6.9859, Validation Accuracy: 51.61%
#
# Epoch [39/50], Loss: 0.0004, Accuracy: 99.98%
# Epoch [39/50], Validation Loss: 7.0090, Validation Accuracy: 51.61%
#
# Epoch [40/50], Loss: 0.0005, Accuracy: 100.00%
# Epoch [40/50], Validation Loss: 6.9914, Validation Accuracy: 51.61%
#
# Epoch [41/50], Loss: 0.0005, Accuracy: 100.00%
# Epoch [41/50], Validation Loss: 6.9925, Validation Accuracy: 51.61%
#
# Epoch [42/50], Loss: 0.0008, Accuracy: 99.98%
# Epoch [42/50], Validation Loss: 6.9928, Validation Accuracy: 51.61%
#
# Epoch [43/50], Loss: 0.0005, Accuracy: 100.00%
# Epoch [43/50], Validation Loss: 6.9910, Validation Accuracy: 51.61%
#
# Epoch [44/50], Loss: 0.0004, Accuracy: 100.00%
# Epoch [44/50], Validation Loss: 6.9887, Validation Accuracy: 51.61%
#
# Epoch [45/50], Loss: 0.0004, Accuracy: 99.98%
# Epoch [45/50], Validation Loss: 6.9902, Validation Accuracy: 51.61%
#
# Epoch [46/50], Loss: 0.0005, Accuracy: 100.00%
# Epoch [46/50], Validation Loss: 6.9889, Validation Accuracy: 51.61%
#
# Epoch [47/50], Loss: 0.0006, Accuracy: 99.98%
# Epoch [47/50], Validation Loss: 6.9894, Validation Accuracy: 51.61%
#
# Epoch [48/50], Loss: 0.0004, Accuracy: 100.00%
# Epoch [48/50], Validation Loss: 6.9903, Validation Accuracy: 51.61%
#
# Epoch [49/50], Loss: 0.0003, Accuracy: 100.00%
# Epoch [49/50], Validation Loss: 6.9905, Validation Accuracy: 51.61%
#
# Epoch [50/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [50/50], Validation Loss: 6.9938, Validation Accuracy: 51.61%

# %%
import torch

torch.save(vit_base_patch16_224.state_dict(), "vit_model.pth")
print("Model saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-67bf08c03fe0> in <cell line: 3>()
#       1 import torch
#       2
# ----> 3 torch.save(vit_base_patch16_224.state_dict(), "vit_model.pth")
#       4 print("Model saved successfully!")
#       5
#
# NameError: name 'vit_base_patch16_224' is not defined

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report

# Ensure model is in evaluation mode
model.eval()

# Store true and predicted labels
y_true = []
y_pred = []

# Run model on test data
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# Convert lists to NumPy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Compute overall metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')  # Sensitivity
f1 = f1_score(y_true, y_pred, average='weighted')

# Compute specificity per class
specificity_per_class = []
class_support = cm.sum(axis=1)  # Total samples per class
for i in range(len(class_names)):
    tn = np.sum(cm) - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])  # True Negatives
    fp = cm[:, i].sum() - cm[i, i]  # False Positives
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0  # Avoid division by zero
    specificity_per_class.append(specificity)

# Compute overall specificity (weighted average)
overall_specificity = np.sum(np.array(specificity_per_class) * class_support) / np.sum(class_support)

# Print overall metrics
print("\nOverall Metrics:")
print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"Precision: {precision:.4f}")
print(f"Sensitivity (Recall): {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Specificity: {overall_specificity:.4f}")  # <-- Overall Specificity added!

# Print class-wise metrics
print("\nClassification Report:")
report = classification_report(y_true, y_pred, target_names=class_names, digits=4)
print(report)

# Print specificity per class
print("\nSpecificity per Class:")
for class_name, spec in zip(class_names, specificity_per_class):
    print(f"{class_name}: {spec:.4f}")

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
